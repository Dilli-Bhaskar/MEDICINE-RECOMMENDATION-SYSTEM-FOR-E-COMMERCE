# %%
import csv
import pandas as pd
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Dilli\Desktop\Copy of Copy of mini1.ipynb Cell 1 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Dilli/Desktop/Copy%20of%20Copy%20of%20mini1.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import csv
#       <a href='vscode-notebook-cell:/c%3A/Users/Dilli/Desktop/Copy%20of%20Copy%20of%20mini1.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dilli/Desktop/Copy%20of%20Copy%20of%20mini1.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
file = pd.read_csv("meddilli.csv")
file2 = pd.read_csv("Medicine_description_withCompany.csv", encoding= 'unicode_escape')
grp = file.groupby(["Description"])
k = list(file.Drug_Name)
file2.head()
# Out:
#                                            Drug_Name Reason  ... NSE_Symbol Rating
# 0               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne  ...  SUNPHARMA      S
# 1  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne  ...    DRREDDY    4.7
# 2                             ACGEL CL NANO Gel 15gm   Acne  ...   DIVISLAB      D
# 3                                ACGEL NANO Gel 15gm   Acne  ...      CIPLA      C
# 4                              Acleen 1% Lotion 25ml   Acne  ...     BIOCON      B
#
# [5 rows x 6 columns]

# %%
drug = [input('Enter the drug name')]
print(drug)
with open("Medicine_description_withCompany.csv",'r', encoding= 'unicode_escape') as file:
    reader= csv.reader(file)
    new_rows = []
    for row in reader:
         #print(row[0])
         if row[0] in drug:
            #print (row)
            new_rows.append([row[2]])
print(new_rows)
# Out:
# Enter the drug nameAcemiz Plus Suspension 60ml
# ['Acemiz Plus Suspension 60ml']
# [['treats prexia']]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfid = TfidfVectorizer(sublinear_tf = True,min_df=5, norm='l2',encoding='latin-1',ngram_range=(1,2),stop_words='english')

features = tfid.fit_transform(file.Description).toarray()

# %%
#from sklearn.feature_selection import chi2

#d = chi2(features,file.Description)
features

# %% [markdown]
# Native Bayes

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(file['Description'], file['Drug_Name'], random_state = 0)

count_vect = CountVectorizer()

X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)





clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
c = clf.predict(count_vect.transform(["treats prexia"]))
#c = c.tolist()
v = c[0]
v
# Out:
# '[\'Aceclomac Plus Suspension 60ml\', \'Acemiz Plus Suspension 60ml\', "Aceto 650mg Tablet 10\'SACETO 100mg Drops 15mlAceto 150mg Drops 15mlAceto 125mg Syrup 30ml", "Acezon Tablet 10\'S", "Acton OR Tablet 10\'S", "Algina 650mg Tablet 10\'SAlgina 250mg Syrup 60mlAlgina 125mg Syrup 60ml", \'Anetol 1gm Infusion 100ml\', "Anglocet Plus Tablet 10\'S", "Arden 250Mg Suspension 60mlARDEN 125mg Suspension 60mlArden 325Mg Tablet 15\'sARDEN 1000mg Tablet 10\'sArden 250Mg Tablet 15\'sARDEN 125mg Tablet 10\'sArden 650Mg Tablet 15\'s", \'Babygesic 250mg Oral Suspension 60mlBabygesic 125mg Suspension 60mlBabygesic Drops 15ml\', \'Biopyrin 250mg Suspension 60ml\', "BRURIFF 400mg Tablet 10\'s", "Calpol 250mg Suspension 60mlCalpol 650mg Tablet 15\'SCalpol 500mg Tablet 1000\'SCalpol 250mg Tablet 15\'SCalpol 500mg Tablet 15\'SCalpol 120mg Suspension 60ml", \'Calpol Paediatric Drops 15ml\', "Centamol 250mg Suspension 60mlCentamol 125mg Syrup 60mlCentamol 650mg Tablet 10\'S", \'Centamol Plus Suspension 60
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split

from sklearn.datasets import load_iris
 
knn = KNeighborsClassifier(n_neighbors=7)
 
knn.fit(X_train_tfidf,y_train)
 
# Predict on dataset which model has not seen before
e = knn.predict(count_vect.transform(["treats prexia"]))
e = e.tolist()
w = e[0]

# %% [markdown]
# **linear svc**

# %%
from sklearn import svm

model = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train_tfidf,y_train)
#rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
#poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
#sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

q = model.predict(count_vect.transform(["treats prexia"]))
print(q==u)

# %%
from operator import itemgetter
print(new_rows)
new = [['ee',3],['3',4]]
print(sorted(new_rows,key= lambda x:x[1]))
# Out:
# []
# []

# %%
######################################################


with open("Medicine_description_withCompany.csv",'r', encoding= 'unicode_escape') as file:
    reader= csv.reader(file)
    new_rows = []
    for row in reader:
         #print(row[0])
         if row[0] in c[0]:
            #print (row)
            new_rows.append([row[0],row[5]])
print(new_rows)

          
#print(len(new_rows),len(c[0]))
#print(c[0])
#print(sorted(new_rows,key= lambda x:x[1]))
# Out:
# [['Aceclomac Plus Suspension 60ml', 'ABB'], ['Acemiz Plus Suspension 60ml', 'AL'], ["Aceto 650mg Tablet 10'SACETO 100mg Drops 15mlAceto 150mg Drops 15mlAceto 125mg Syrup 30ml", 'G'], ["Acezon Tablet 10'S", 'I'], ["Acton OR Tablet 10'S", 'ALEM'], ["Algina 650mg Tablet 10'SAlgina 250mg Syrup 60mlAlgina 125mg Syrup 60ml", 'GL'], ['Anetol 1gm Infusion 100ml', 'JB'], ["Anglocet Plus Tablet 10'S", 'S'], ["Arden 250Mg Suspension 60mlARDEN 125mg Suspension 60mlArden 325Mg Tablet 15'sARDEN 1000mg Tablet 10'sArden 250Mg Tablet 15'sARDEN 125mg Tablet 10'sArden 650Mg Tablet 15's", 'R'], ['Babygesic 250mg Oral Suspension 60mlBabygesic 125mg Suspension 60mlBabygesic Drops 15ml', 'D'], ['Biopyrin 250mg Suspension 60ml', 'C'], ["BRURIFF 400mg Tablet 10's", 'B'], ["Calpol 250mg Suspension 60mlCalpol 650mg Tablet 15'SCalpol 500mg Tablet 1000'SCalpol 250mg Tablet 15'SCalpol 500mg Tablet 15'SCalpol 120mg Suspension 60ml", 'AU'], ['Calpol Paediatric Drops 15ml', 'T'], ["Centamol 250mg Suspension 60mlCent
# ...

# %%
for i in c[0]:
  first = file2.loc(i)
  print(first)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: '['
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-f741b61d72fc> in <module>()
#       1 for i in c[0]:
# ----> 2   first = file2.loc(i)
#       3   print(first)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     582
#     583         if axis is not None:
# --> 584             axis = self.obj._get_axis_number(axis)
#     585         new_self.axis = axis
#     586         return new_self
#
# ...

# %%
c

# %%
# Out:
# [ True]
